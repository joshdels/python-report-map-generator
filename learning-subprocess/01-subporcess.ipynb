# %% [markdown]
# ### Introduction

# %%
# TO PDF
import subprocess

output_folder = "../results/"

subprocess.run([
    "libreoffice",
    "--headless",
    "--convert-to",
    "pdf",
    "../results/exercise6.docx"
], cwd=output_folder)
# Out:
# ...
# convert /home/joshua/Documents/python-report-map-generator/results/exercise6.docx as a Writer document -> /home/joshua/Documents/python-report-map-generator/results/exercise6.pdf using filter : writer_pdf_Export
# CompletedProcess(args=['libreoffice', '--headless', '--convert-to', 'pdf', '../results/exercise6.docx'], returncode=0)
